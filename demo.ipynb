# %% [markdown]
# ### Imports and data loading

# %%
import pandas as pd
import geopandas as gpd
import folium
import skmob
from shapely.geometry import LineString
from skmob.preprocessing.detection import stay_locations
from skmob.preprocessing.filtering import filter
from skmob.preprocessing.compression import compress
import numpy as np

# %%
# 6 cargo ships from Brest dataset 
data = pd.read_csv('data.csv')
data.t = pd.to_datetime(data.t, unit = 's')

# %% [markdown]
# ### Data preprocessing

# %%
# Use skmob TrajDataFrame
data = skmob.TrajDataFrame(data, latitude='lat', longitude='lon', datetime='t', user_id='sourcemmsi', timestamp=True)

# %%
data = filter(data, speed_kmh=100)

# %%
# Compress data for more light weight LineStrings
cdata = compress(data, spatial_radius_km=0.2)

# %%
cdata = cdata.to_geodataframe()
# Out:
# /home/jussiste/.local/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
cdata.set_crs(4326, allow_override=True,inplace=True)
# Out:
#              uid  navigationalstatus  rateofturn  speedoverground  \
# 0      228020700                   0           0             16.5
# 1      228020700                   0           0             16.5
# 2      228020700                   0           0             15.0
# 3      228020700                   0           0             14.9
# 4      228020700                   0           0             13.3
# ...          ...                 ...         ...              ...
# 12944  538002973                   0           0             12.3
# 12945  538002973                   0        -126             12.1
# 12946  538002973                   0           0             12.3
# 12947  538002973                   0           0             12.6
# 12948  538002973                   0           0             12.0
#
#        courseoverground  trueheading       lng        lat            datetime  \
# 0                 205.0          203 -5.918172  48.695835 2015-10-02 13:33:15
# 1                 206.0          200 -5.919533  48.693910 2015-10-02 13:33:49
# 2                 154.0          145 -5.908808  48.633940 2015-10-02 13:48:31
# 3                 154.0          145 -5.907538  48.632195 2015-10-02 13:48:59
# 4                 138.0          137 -5.442703  48.185074 2015-10-02 16:06:19
# ...                 ...          ...       ...        ...                 ...
# 12944             319.0          318 -5.183365  48.310318 2015-12-11 23:04:31
# 12945             321.0          312 -5.187465  48.313658 2015-12-11 23:05:31
# 12946             291.0          291 -5.206332  48.319466 2015-12-11 23:09:59
# 12947             291.0          291 -5.212957  48.321192 2015-12-11 23:11:10
# 12948             308.0          307 -5.279665  48.344017 2015-12-11 23:26:30
#
#                         geometry
# 0      POINT (-5.91817 48.69584)
# 1      POINT (-5.91953 48.69391)
# 2      POINT (-5.90881 48.63394)
# 3      POINT (-5.90754 48.63220)
# 4      POINT (-5.44270 48.18507)
# ...                          ...
# 12944  POINT (-5.18337 48.31032)
# 12945  POINT (-5.18746 48.31366)
# 12946  POINT (-5.20633 48.31947)
# 12947  POINT (-5.21296 48.32119)
# 12948  POINT (-5.27966 48.34402)
#
# [12949 rows x 10 columns]

# %%
cdata.sort_values(['uid', 'datetime'], inplace = True)

# %%
# Detect areas where the ships have stopped
stops = stay_locations(data, minutes_for_a_stop=120, spatial_radius_km=0.1)
stops.sort_values(['uid', 'datetime'], inplace = True)
stops['next_uid'] = stops.uid.shift(-1)
stops['next_time'] = stops.datetime.shift(-1)

# %%
trajs = []
for i, row in stops.iterrows():
    if row['next_uid']!=row['uid']:
        continue
    trajs.append(cdata[(cdata.uid == row.uid) & (cdata.datetime>row.datetime) & (cdata.datetime<=row.next_time)])

# %%
data = data.to_geodataframe()
# Out:
# /home/jussiste/.local/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
def trajectories(trajs):
    t = []
    for traj in trajs:
        if len(traj)<=1:
            continue
        t.append(np.append(traj.iloc[0].values, [traj.iloc[len(traj)-1].datetime, traj.iloc[len(traj)-1].geometry, LineString(traj.geometry.values)]))
    return pd.DataFrame(t, columns=[*trajs[0].columns, "end_time", "end_coords", "trajectory"])

# %%
trajs_df = trajectories(trajs)

# %% [markdown]
# ### Data mapping

# %%
# Initializing the map object
m = folium.Map(location=[stops.lat.mean(), stops.lng.mean()], 
                 zoom_start=10, control_scale=True)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c367a021ed8b63ec5c6af8a93171415 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c367a021ed8b63ec5c6af8a93171415&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c367a021ed8b63ec5c6af8a93171415 = L.map(
#                 &quot;map_1c367a021ed8b63ec5c6af8a93171415&quot;,
#                 {
#                     center: [48.21830136585366, -4.665801278658536],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_1c367a021ed8b63ec5c6af8a93171415);
#
#
#
#
#
#             var tile_layer_036e3d6e97e81a3b9b3dceafc33a395b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1c367a021ed8b63ec5c6af8a93171415);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
### Adding trajectory data to map
def add_ship_trajectories(lines, m, feature_group, color):
    for _, r in lines.items():
        sim_geo = gpd.GeoSeries(r)
        geo_j = sim_geo.to_json()
        geo_j = folium.GeoJson(data=geo_j,
                               style_function=lambda x: {"opacity": 0.50, "color": color,}).add_to(feature_group)
    feature_group.add_to(m)

fg = folium.map.FeatureGroup(name='Trajectories', show = True)
add_ship_trajectories(trajs_df.trajectory, m, fg, 'green')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c38d9a4832077b5aa3da0e5e6e96428 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c38d9a4832077b5aa3da0e5e6e96428&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c38d9a4832077b5aa3da0e5e6e96428 = L.map(
#                 &quot;map_5c38d9a4832077b5aa3da0e5e6e96428&quot;,
#                 {
#                     center: [48.21830136585366, -4.665801278658536],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5c38d9a4832077b5aa3da0e5e6e96428);
#
#
#
#
#
#             var tile_layer_a383cb4722fbdcde41c4506ad4bcd134 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5c38d9a4832077b5aa3da0e5e6e96428);
#
#
#             var feature_group_70b8bb1ddf10f153496e7ad4273cbe55 = L.featureGroup(
#                 {}
#             ).addTo(map_5c38d9a4832077b5aa3da0e5e6e96428);
#
#
#         function geo_json_7befe650b67e54c6d54c0f61cbe71c32_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;opacity&quot;: 0.5};
#             }
#         }
#
#         function geo_json_7befe650b67e54c6d54c0f61cbe71c32_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7befe650b67e54c6d54c0f61cbe71c32 = L.geoJson(null, {
#                 onEachFeature: geo_json_7befe650b67e54c6d54c0f61cbe71c32_onEachFeature,
#
#                 style: geo_json_7befe650b67e54c6d54c0f61cbe71c32_styler,
#         });
#
#         function geo_json_7befe650b67e54c6d54c0f61cbe71c32_add (data) {
#             geo_json_7befe650b67e54c6d54c0f61cbe71c32
#                 .addData(data)
#                 .addTo(feature_group_70b8bb1ddf10f153496e7ad4273cbe55);
#         }
#             geo_json_7befe650b67e54c6d54c0f61cbe71c32_add({&quot;bbox&quot;: [-5.4427032, 47.489708, -3.9055066, 48.185074], &quot;features&quot;: [{&quot;bbox&quot;: [-5.4427032, 47.489708, -3.9055066, 48.185074], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-5.4427032, 48.185074], [-5.402745, 48.154354], [-5.365538, 48.12382], [-5.35381915, 48.115322], [-5.332687, 48.099895], [-5.328729, 48.096778], [-5.3107567, 48.0824], [-5.3065435, 48.078961500000005], [-5.30434815, 48.077163], [-5.3025084, 48.075657], [-5.299713, 48.073353], [-5.2978018, 48.071813500000005], [-5.29499065, 48.069608], [-5.29271005, 48.067857], [-5.2898035, 48.06572], [-5.2876983, 
956257], [-5.070872, 47.955307], [-5.0672239999999995, 47.953804], [-5.0637236, 47.95237], [-5.06034, 47.950984000000005], [-5.0571865, 47.949698999999995], [-5.05495, 47.9487925], [-5.05211, 47.947628], [-5.0475116, 47.94574], [-5.045367, 47.94486], [-5.0430367, 47.9438835], [-5.039943, 47.942596], [-5.03773, 47.941673], [-5.033837, 47.94005], [-5.03080425, 47.9387725], [-5.02

# %%
### Add extra tile layers

# Satellite imagery
folium.TileLayer(
        tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
        attr = 'Esri',
        name = 'Esri Satellite',
        overlay = False,
        control = True
       ).add_to(m)

# Ocean bathymetry
ocean = folium.TileLayer(
        tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/Ocean/World_Ocean_Base/MapServer/tile/{z}/{y}/{x}',
        attr = 'Ocean',
        name = 'Ocean',
        overlay = False,
        control = True
       ).add_to(m)

# Ocean additional reference 

folium.TileLayer(
        tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/Ocean/World_Ocean_Reference/MapServer/tile/{z}/{y}/{x}',
        attr = 'Ocean_ref',
        name = 'Ocean_ref',
        overlay = True,
        control = True
       ).add_to(m)

folium.LayerControl(collapsed=False).add_to(m)

# %% [markdown]
# More tile layers can be found at [https://server.arcgisonline.com/arcgis/rest/services]()

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5709450a21ff4ce8999487da70247fbf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5709450a21ff4ce8999487da70247fbf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5709450a21ff4ce8999487da70247fbf = L.map(
#                 &quot;map_5709450a21ff4ce8999487da70247fbf&quot;,
#                 {
#                     center: [48.21830136585366, -4.665801278658536],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5709450a21ff4ce8999487da70247fbf);
#
#
#
#
#
#             var tile_layer_9d7b060711bd0a6a25730ba5031fbd97 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5709450a21ff4ce8999487da70247fbf);
#
#
#             var feature_group_6c26ad3a41d45f10de4b7cc3c4bc9002 = L.featureGroup(
#                 {}
#             ).addTo(map_5709450a21ff4ce8999487da70247fbf);
#
#
#         function geo_json_c60ce0da2f7949a7a23c4ad0071bd8c0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;opacity&quot;: 0.5};
#             }
#         }
#
#         function geo_json_c60ce0da2f7949a7a23c4ad0071bd8c0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c60ce0da2f7949a7a23c4ad0071bd8c0 = L.geoJson(null, {
#                 onEachFeature: geo_json_c60ce0da2f7949a7a23c4ad0071bd8c0_onEachFeature,
#
#                 style: geo_json_c60ce0da2f7949a7a23c4ad0071bd8c0_styler,
#         });
#
#         function geo_json_c60ce0da2f7949a7a23c4ad0071bd8c0_add (data) {
#             geo_json_c60ce0da2f7949a7a23c4ad0071bd8c0
#                 .addData(data)
#                 .addTo(feature_group_6c26ad3a41d45f10de4b7cc3c4bc9002);
#         }
#             geo_json_c60ce0da2f7949a7a23c4ad0071bd8c0_add({&quot;bbox&quot;: [-5.4427032, 47.489708, -3.9055066, 48.185074], &quot;features&quot;: [{&quot;bbox&quot;: [-5.4427032, 47.489708, -3.9055066, 48.185074], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-5.4427032, 48.185074], [-5.402745, 48.154354], [-5.365538, 48.12382], [-5.35381915, 48.115322], [-5.332687, 48.099895], [-5.328729, 48.096778], [-5.3107567, 48.0824], [-5.3065435, 48.078961500000005], [-5.30434815, 48.077163], [-5.3025084, 48.075657], [-5.299713, 48.073353], [-5.2978018, 48.071813500000005], [-5.29499065, 48.069608], [-5.29271005, 48.067857], [-5.2898035, 48.06572], [-5.2876983, 48.064163], [-5.2856606500000005, 48.062657], [-5.2830634, 48.06072], [-5.281045649999999, 48.0592465], [-5.278965, 48.05774], [-5.2764025, 48.055847], [-5.27407005, 48.054162000000005], [-5.271713200000001, 48.052454], [-5.2690935, 48.050552], [-5.2676582, 48.049516999999994], [-5.2652874999999995, 48.047799999999995], [-5.2629383999999995, 48.046085000000005], [-5.2606225, 48.0443925], [-5.25826275, 48.042637], [-5.25629, 48.04116], [-5.2542258, 48.0396195], [-5.2512775000000005, 48.0373995], [-5.24932835, 48.0359475], [-5.24725775, 48.0344085], [-5.24472165, 48.032475000000005], [-5.2401633, 48.029068], [-5.230078, 48.022087], [-5.2209151, 48.016072], [-5.218005, 48.01441], [-5.2110867, 48.011125500000006], [-5.2007842, 48.006403500000005], [-5.1985335, 48.00549], [-5.1953416, 48.004272], [-5.1902417, 48.00235], [-5.1875715, 48.00134], [-5.1851743500000005, 48.00044], [-5.1819115, 47.999226], [-5.1797085, 47.998413], [-5.17727, 47.997513], [-5.17569, 47.996925], [-5.1724415, 47.995728], [-5.1661267, 47.993412], [-5.1629133, 47.992233], [-5.1597233, 47.9910625], [-5.1568892, 47.990021], [-5.1544608499999995, 47.989121499999996], [-5.1500382, 47.987465], [-5.147971, 47.98668], [-5.1451735, 47.98562], [-5.142655, 47.984657], [-5.1403, 47.983757], [-5.137787, 47.98279], [-5.135445, 47.98188], [-5.1321683, 47.980587], [-5.1298585, 47.97968], [-5.12696735, 47.978537], [-5.1242585, 47.977444], [-5.121178, 47.9762], [-5.1187234, 47.975212], [-5.1163516, 47.974262], [-5.1140084, 47.973312], [-5.1116767, 47.972355], [-5.10934, 47.971386], [-5.1070065, 47.9704], [-5.10382, 47.96904], [-5.1015534, 47.968094], [-5.0992023, 47.96711500000001], [-5.096835, 47.96615], [-5.0945516, 47.9652], [-5.0921035, 47.964188], [-5.0898166, 47.963234], [-5.08582, 47.961533], [-5.083463500000001, 47.9605375], [-5.078815, 47.95859], [-5.07600435, 47.9574265], [-5.0731835, 47.956257], [-5.070872, 47.955307], [-5.0672239999999995, 47.953804], [-5.0637236, 47.95237], [-5.06034, 47.950984000000005], [-5.0571865, 47.949698999999995], [-5.05495, 47.9487925], [-5.05211, 47.947628], [-5.0475116, 47.94574], [-5.045367, 47.94486], [-5.0430367, 47.9438835], [-5.039943, 47.942596], [-5.03773, 47.941673], [-5.033837, 47.94005], [-5.03080425, 47.9387725], [-5.02

# %%
stops = stops.to_geodataframe()
# Out:
# /home/jussiste/.local/lib/python3.10/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
pip freeze |grep folium
# Out:
# folium==0.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Mapping point based data
m = folium.Map(location=[stops.lat.mean(), stops.lng.mean()], 
                 zoom_start=10, control_scale=True)

marker_cluster = folium.plugins.MarkerCluster().add_to(m)

for _, row in stops.iterrows():
    print(row)
    #folium.Marker(row.geometry).add_to(marker_cluster)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [132], line 5
#       1 # Mapping point based data
#       2 m = folium.Map(location=[stops.lat.mean(), stops.lng.mean()],
#       3                  zoom_start=10, control_scale=True)
# ----> 5 marker_cluster = folium.plugins.MarkerCluster("Stop points").add_to(m)
#       7 for _, row in stops.iterrows():
#       8     print(row)
#
# File ~/.local/lib/python3.10/site-packages/folium/plugins/marker_cluster.py:99, in MarkerCluster.__init__(self, locations, popups, icons, name, overlay, control, show, icon_create_function, options, **kwargs)
#      96 self._name = "MarkerCluster"
#      98 if locations is not None:
# ---> 99     locations = validate_locations(locations)
#     100     for i, location in enumerate(locations):
#     101         self.add_child(
#     102             Marker(
#     103                 location, popup=popups and popups[i], icon=icons and icons[i]
#     104             )
#     105         )
#
# File ~/.local/lib/python3.10/site-packages/folium/utilities.py:103, in validate_locations(locations)
#     101     raise ValueError("Locations is empty.")
#     102 try:
# --> 103     float(next(iter(next(iter(next(iter(locations)))))))
#     104 except (TypeError, StopIteration):
#     105     # locations is a list of coordinate pairs
#     106     return [validate_location(coord_pair) for coord_pair in locations]
#
# ValueError: could not convert string to float: 'S'
